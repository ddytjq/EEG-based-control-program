# %%
# !python drive/retrain.py --bottleneck_dir=drive/bottlenecks --model_dir=drive/inception --output_graph=drive/eeg_graph.pb --output_labels=drive/eeg_labels.txt --image_dir drive/dataset --how_many_training_steps 1000
# Out:
# ^C
# Traceback (most recent call last):
#   File "drive/retrain.py", line 1326, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/usr/local/lib/python2.7/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "drive/retrain.py", line 982, in main
#     maybe_download_and_extract(model_info['data_url'])
#   File "drive/retrain.py", line 340, in maybe_download_and_extract
#     tarfile.open(filepath, 'r:gz').extractall(dest_directory)
#   File "/usr/lib/python2.7/tarfile.py", line 2081, in extractall
#     self.extract(tarinfo, path)
#   File "/usr/lib/python2.7/tarfile.py", line 2118, in extract
#     self._extract_member(tarinfo, os.path.join(path, tarinfo.name))
#   File "/usr/lib/python2.7/tarfile.py", line 2194, in _extract_member
#     self.makefile(tarinfo, targetpath)
#   File "/usr/lib/python2.7/tarfile.py", line 2235, in makefile
#     copyfileobj(source, target)
# ...

# %%
# !ls drive
# Out:
# 창고  1학년  3학년  colab	inception	retrain.py
# 사진  2학년  4학년  dataset	label_image.py	Untitled0.ipynb

# %%
# !python3 drive/retrain.py --bottleneck_dir=drive/bottlenecks --model_dir=drive/inception --output_graph=drive/eeg_graph.pb --output_labels=drive/eeg_labels.txt --image_dir drive/dataset --how_many_training_steps 1000
# Out:
# Traceback (most recent call last):
#   File "drive/retrain.py", line 1052, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 125, in run
#     _sys.exit(main(argv))
#   File "drive/retrain.py", line 768, in main
#     maybe_download_and_extract()
#   File "drive/retrain.py", line 305, in maybe_download_and_extract
#     tarfile.open(filepath, 'r:gz').extractall(dest_directory)
#   File "/usr/lib/python3.6/tarfile.py", line 2007, in extractall
#     numeric_owner=numeric_owner)
#   File "/usr/lib/python3.6/tarfile.py", line 2049, in extract
#     numeric_owner=numeric_owner)
#   File "/usr/lib/python3.6/tarfile.py", line 2111, in _extract_member
#     os.makedirs(upperdirs)
#   File "/usr/lib/python3.6/os.py", line 220, in makedirs
#     mkdir(name, mode)
# OSError: [Errno 16] Device or resource busy: 'drive/inception'

# %%
# !python3 drive/retrain.py --bottleneck_dir = ./drive/workspace/bottlenecks --model_dir=./drive/workspace/inception --output_graph=./drive/eeg_graph.pb --output_labels=./drive/workspace/eeg_labels.txt --image_dir ./drive/workspace/dataset --how_many_training_steps 1000
# Out:
# 2018-07-13 12:19:02.914204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:897] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-07-13 12:19:02.914583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1392] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 458.12MiB
# 2018-07-13 12:19:02.914631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1471] Adding visible gpu devices: 0
# 2018-07-13 12:19:03.328486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:952] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-07-13 12:19:03.328556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:958]      0
# 2018-07-13 12:19:03.328577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:971] 0:   N
# ...
